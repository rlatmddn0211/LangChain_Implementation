# %% [markdown]
# **Stuff Documents**

# %%
from langchain.embeddings import OpenAIEmbeddings,CacheBackedEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.vectorstores import FAISS
from langchain.text_splitter import CharacterTextSplitter
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm=ChatOpenAI()

cache_dir=LocalFileStore("../.cache/")

splitter=CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,  
)

loader=UnstructuredFileLoader("../files/chapter_one.txt")

docs=loader.load_and_split(text_splitter=splitter)
embeddings=OpenAIEmbeddings()
cached_embeddings=CacheBackedEmbeddings.from_bytes_store(
    embeddings,cache_dir 
)
vectorstore=FAISS.from_documents(docs,cached_embeddings)

chain=RetrievalQA.from_chain_type(
    llm=llm,
    chain_type='stuff',
    retriever=vectorstore.as_retriever(),

)
chain.run("Where does Winston live?")
# Out:
# 'Winston lives in Victory Mansions, a building with seven flights of stairs, where he resides on the seventh floor.'

# %% [markdown]
# **Refine Documents**

# %%
from langchain.embeddings import OpenAIEmbeddings,CacheBackedEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.vectorstores import FAISS
from langchain.text_splitter import CharacterTextSplitter
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm=ChatOpenAI()

cache_dir=LocalFileStore("../.cache/")

splitter=CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,  
)

loader=UnstructuredFileLoader("../files/chapter_one.txt")

docs=loader.load_and_split(text_splitter=splitter)
embeddings=OpenAIEmbeddings()
cached_embeddings=CacheBackedEmbeddings.from_bytes_store(
    embeddings,cache_dir 
)
vectorstore=FAISS.from_documents(docs,cached_embeddings)

chain=RetrievalQA.from_chain_type(
    llm=llm,
    chain_type='refine',
    retriever=vectorstore.as_retriever(),

)
chain.run("Where does Winston live?")
# Out:
# "In addition to living in Victory Mansions, Winston also works at the Ministry of Truth, one of the four ministries that govern Oceania. The Ministry of Truth is responsible for propaganda and rewriting historical records to align with the Party's current version of truth. Winston's job at the ministry involves altering past newspaper articles to reflect the Party's ever-changing narrative. Despite his compliance at work, Winston harbors rebellious thoughts against the oppressive government and seeks ways to resist their control. His living situation in Victory Mansions reflects the decay and oppression present in Oceania, where citizens like Winston are constantly surveilled and restricted in their actions."
