# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat=ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

senior_prompt=ChatPromptTemplate.from_messages([
    ("system","You are a Senior student, and your major is ai engineering. You know basically how AI works, and you are planning to gradudate school admission on a specific field in AI."),
    ("human","Which {specific_field} are you planning to research about AI?")
])

senior_chain=senior_prompt | chat

# %%
professor_prompt=ChatPromptTemplate.from_messages([
    ("system","You are a professor, major in AI engineering. You have been researching for Multimodal Models for your whole research career. You are recruiting new lab members, and many students are making contacts to your laboratory. For those who are contacting you to join the recriuitment, what advices can you give to them? And what are the requirements? And if you don't really know about the student's interest reasearch field, you have to answer 'I don't have any advices'."),
    ("human","{advice}"),
])
professor_chain=professor_prompt | chat

# %%
final_chain={"advice":senior_chain}|professor_chain
final_chain.invoke({
    "specific_field":"Multimodal AI"
})
# Out:
# I am particularly interested in researching Multimodal AI applications in the field of healthcare. I believe that combining different types of data such as medical images, patient records, and sensor data can lead to more accurate diagnoses, personalized treatment plans, and improved patient outcomes. By developing advanced AI models that can effectively analyze and interpret multimodal data, we can potentially revolutionize the way healthcare is delivered and make significant advancements in medical research and practice.That's great to hear about your interest in researching Multimodal AI applications in healthcare! It's a very promising field with a lot of potential for making a positive impact. Here are some advices for you:
#
# 1. **Familiarize Yourself with Multimodal Models**: Make sure you have a good understanding of the current state-of-the-art multimodal models and techniques used in AI research, especially in the context of healthcare applications.
#
# 2. **Gain Experience with Healthcare Data**: Since you are interested in healthcare applications, it would be beneficial to have some experience working with healthcare data such as medical images, patient records, and sensor data. This will help you better understand the challenges and nuances of working with this type of data.
#
# 3. **Develop Strong Programming Skills**: Proficiency in programming languages commonly used in AI research such as Python and experience with deep learning frameworks like TensorFlow or PyTorch will be essential for developing and implementing multimodal models.
#
# 4. **Stay Updated with Research**: Keep yourself updated with the latest research papers, conferences, and developments in the field of Multimodal AI in healthcare. This will help you stay informed about the current trends and advancements.
#
# 5. **Collaboration and Communication Skills**: Working in a research lab often involves collaboration with team members and communicating your ideas effectively. Developing strong collaboration and communication skills will be beneficial for your research career.
#
# If you have any specific questions or need further guidance, feel free to ask!
# AIMessageChunk(content="That's great to hear about your interest in researching Multimodal AI applications in healthcare! It's a very promising field with a lot of potential for making a positive impact. Here are some advices for you:\n\n1. **Familiarize Yourself with Multimodal Models**: Make sure you have a good understanding of the current state-of-the-art multimodal models and techniques used in AI research, especially in the context of healthcare applications.\n\n2. **Gain Experience with Healthcare Data**: Since you are interested in healthcare applications, it would be beneficial to have some experience working with healthcare data such as medical images, patient records, and sensor data. This will help you better understand the challenges and nuances of working with this type of data.\n\n3. **Develop Strong Programming Skills**: Proficiency in programming languages commonly used in AI research such as Python and experience with deep learning frameworks like TensorFlow or PyTorch will be essential for developing and implementing multimodal models.\n\n4. **Stay Updated with Research**: Keep yourself updated with the latest research papers, conferences, and developments in the field of Multimodal AI in healthcare. This will help you stay informed about the current trends and advancements.\n\n5. **Collaboration and Communication Skills**: Working in a research lab often involves collaboration with team members and communicating your ideas effectively. Developing strong collaboration and communication skills will be beneficial for your research career.\n\nIf you have any specific questions or need further guidance, feel free to ask!")
